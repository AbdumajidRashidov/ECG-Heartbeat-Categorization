# %% [markdown]
# # In this task we are going to perform a classification task.
#
# # The data contains the exam 1 and exam 2 scores of the student, and if they are admitted or not.
#
# # The task is to classify whether the student will be admitted or not based on the exam 1 and exam 2 score.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from google.colab import files
#       2 uploaded = files.upload()
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# Import the lbraries

# %%
# Your code to important Libraries - You need to import multiple libraries.
from scipy import optimize
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Read the data and split it into X and y.
#
# # X is the exam scores and y is the binary variable to determine if a student is admitted or not.

# %%
data = np.loadtxt("ex2data1.txt", delimiter=',')  # Note - The data is read using numpy rather than pandas.
X = data[:, [0, 1]]
y = data[:, 2]

# %% [markdown]
# # Print some samples of the input X

# %%
# Your code to print samples of X
X[:5]
# Out:
# array([[34.62365962, 78.02469282],
#        [30.28671077, 43.89499752],
#        [35.84740877, 72.90219803],
#        [60.18259939, 86.3085521 ],
#        [79.03273605, 75.34437644]])

# %% [markdown]
# # Print some samples of the output y

# %%
# Your code to print samples of y
y[:5]
# Out:
# array([0., 0., 0., 1., 1.])

# %% [markdown]
# # Plot the data

# %%
plt.figure()
plt.scatter(X[y == 1][:, 0], X[y == 1][:, 1], label="Admitted")
# Your code to plot all samples with target value 0


plt.xlabel("Exam 1 score")
plt.ylabel("Exam 2 score")
plt.legend()
plt.show()

# %% [markdown]
# # Function for the Sigmoid
#
# # $g(z) = \frac {1}{1 + e ^{-z}}$

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %% [markdown]
# # Plot the sigmod function.
#
# # X axis will have numbers from -10 to 10 (could be any other range). Hint - You can use np.linespace or np.arange methods.
#
# # y will have sigmoid function values.

# %%
# Your code to plot x vs sigmoid (x) function. x is range from -10 to 10. 
# y can be obtained by calling the function defined earlier

x = np.linspace(-10, 10, 200)  # 200 points for a smooth curve

# Calculating y values using the sigmoid function
y = sigmoid(x)

# Plotting x vs sigmoid(x)
plt.plot(x, y)
plt.title("Sigmoid Function")
plt.xlabel("x")
plt.ylabel("Sigmoid(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# # Define a function to calculate the cost.
#
# ![image.png](data:image/png;base64,...)
#
# # Hint - Use the sigmoid function output, np.dot, and np.log functions.

# %%
def cost(theta, X, y):
    m = len(y)  # Number of training examples
    h = sigmoid(np.dot(X, theta))  # The hypothesis predictions for all examples
    error = -y * np.log(h) - (1 - y) * np.log(1 - h)
    J = (1/m) * np.sum(error)  # The cost
    return J

# %% [markdown]
# # Define a function to calculate gradients of cost function with respect to the theta.
#
# ![image.png](attachment:image.png)

# %%
def gradient(theta, X, y):
    h = sigmoid(np.dot(X, theta))
    grad = np.dot(X.T, h - y) / X.shape[0]
    return grad

# %% [markdown]
# # Combine everything together.
#
# # This time we will use optimize function from scipy rather than writing gradient descent code from scratch

# %%
X = np.random.rand(5, 2)

X_train = np.hstack((np.ones((X_dummy.shape[0], 1)), X))

def sigmoid(z):
    return 1 / (1 + np.exp(-z))

print("Samples of X_train:")
print(X_train)
# Out:
# Samples of X_train:
# [[1.         0.8741044  0.54627643]
#  [1.         0.97639092 0.40489286]
#  [1.         0.06274262 0.1458833 ]
#  [1.         0.29327463 0.03556846]
#  [1.         0.3735738  0.97853349]]

# %%
# initiate 'theta' with zeros:
theta = np.array([0, 0, 0])

# Your code to print 'theta'
print("Theta initialized:", theta)
# Out:
# Theta initialized: [0 0 0]

# %%
res = optimize.minimize(fun=cost, x0=theta, args=(X_train, y),
                        method='Newton-CG', jac=gradient)    # Note - Optimization method is Newton - CG rather that 
                                                    # gradient descent. You can use other optimization methods too.
print(res.fun)  # 0.203
print(res.x)  # -25.161 0.206 0.201
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 res = optimize.minimize(fun=cost, x0=theta, args=(X_train, y),
#       2                         method='Newton-CG', jac=gradient)    # Note - Optimization method is Newton - CG rather that
#       3                                                     # gradient descent. You can use other optimization methods too.
#       4 print(res.fun)  # 0.203
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/scipy/optimize/_minimize.py:707, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     705     res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     706 elif meth == 'newton-cg':
# --> 707     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     708                              **options)
#     709 elif meth == 'l-bfgs-b':
#     710     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     711                            callback=callback, **options)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/scipy/optimize/_optimize.py:2007, in _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback, xtol, eps, maxiter, disp, return_all, **unknown_options)
#    2005 x0 = asarray(x0).flatten()
#    2006 # TODO: add hessp (callable or FD) to ScalarFunction?
# -> 2007 sf = _prepare_scalar_function(
#    2008     fun, x0, jac, args=args, epsilon=eps, hess=hess
#    2009 )
#    2010 f = sf.fun
#    2011 fprime = sf.grad
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/scipy/optimize/_optimize.py:383, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     379     bounds = (-np.inf, np.inf)
#     381 # ScalarFunction caches. Reuse of fun(x) during grad
#     382 # calculation reduces overall function evaluations.
# --> 383 sf = ScalarFunction(fun, x0, args, grad, hess,
#     384                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     386 return sf
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:158, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     155     self.f = fun_wrapped(self.x)
#     157 self._update_fun_impl = update_fun
# --> 158 self._update_fun()
#     160 # Gradient evaluation
#     161 if callable(grad):
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     249 def _update_fun(self):
#     250     if not self.f_updated:
# --> 251         self._update_fun_impl()
#     252         self.f_updated = True
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     154 def update_fun():
# --> 155     self.f = fun_wrapped(self.x)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# Cell In[61], line 4, in cost(theta, X, y)
#       2 m = len(y)  # Number of training examples
#       3 h = sigmoid(np.dot(X, theta))  # The hypothesis predictions for all examples
# ----> 4 error = -y * np.log(h) - (1 - y) * np.log(1 - h)
#       5 J = (1/m) * np.sum(error)  # The cost
#       6 return J
#
# ValueError: operands could not be broadcast together with shapes (200,) (5,)

# %% [markdown]
# # Plotting the decision boundary

# %%
def plotDecisionBoundary(theta, X, y):
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                         np.arange(y_min, y_max, 0.1))
    X_plot = np.c_[xx.ravel(), yy.ravel()]
    X_plot = np.hstack((np.ones((X_plot.shape[0], 1)), X_plot))
    y_plot = np.dot(X_plot, theta).reshape(xx.shape)

    plt.figure()
    plt.scatter(X[y == 1][:, 0], X[y == 1][:, 1], label="Admitted")
    plt.scatter(X[y == 0][:, 0], X[y == 0][:, 1], label="Not admitted")
    plt.contour(xx, yy, y_plot, levels=[0])
    plt.xlabel("Exam 1 score")
    plt.ylabel("Exam 2 score")
    plt.legend()
    plt.show()

# %%
plotDecisionBoundary(res.x, X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 plotDecisionBoundary(res.x, X, y)
#
# NameError: name 'res' is not defined

# %% [markdown]
# # Getting the output - Probabilities.
#
# # What will be the output 1/0 for the following probability?

# %%
prob = sigmoid(np.dot(np.array([1, 45, 85]), res.x))
print(prob)  # 0.775 +/- 0.002
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 prob = sigmoid(np.dot(np.array([1, 45, 85]), res.x))
#       2 print(prob)
#
# NameError: name 'res' is not defined

# %% [markdown]
# # Making predictions
#
# # First, we get input X
#
# # Then probability using sigmod and updated theta values.
#
# # Then we will get output 1/0 based on the probability.

# %%
def predict(theta, X):
    X_train = np.hstack((np.ones((X.shape[0], 1)), X))

    # Your code to calculate the probability and convert it to 0 and 1 which will be returned. May be 2-3 lines of code.

# %% [markdown]
# #  Calculating accuracy - number of correct classification/total number of classification.

# %%
np.mean(predict(res.x, X) == y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 np.mean(predict(res.x, X) == y)
#
# NameError: name 'res' is not defined

# %% [markdown]
# # **Important-** Document in your lab logbook, final accuracy and the  encrypted value of the accuracy obtained after after multiplying accuracy by your SID i.e. accuracy*SID.

# %% [markdown]
# # **The rest of the notebook is optional. You are encouraged to complete it. But, if you have not, marks will not be deducted.**
#
# # Using SKlearn library to perform logistic regression task.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, accuracy_score
from matplotlib.colors import ListedColormap

# %% [markdown]
# # Splitting the data into training and test sets

# %%
# Your cose to split the data using sklearn train_test_split

# %% [markdown]
# # Scaling the data - Converting everthing between 0-1

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 3
#       1 sc = StandardScaler()
#       2 X_train = sc.fit_transform(X_train)
# ----> 3 X_test = sc.transform(X_test)
#
# NameError: name 'X_test' is not defined

# %% [markdown]
# # Running Logistc Regression on training data -
#
# # Remember - any kind of fit methiod  will be always used for the training data.

# %%
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 classifier = LogisticRegression(random_state = 0)
# ----> 2 classifier.fit(X_train, y_train)
#
# NameError: name 'y_train' is not defined

# %% [markdown]
# Making a prediction on the classifier.

# %% [markdown]
# # Making a prediction on the test set dataset.

# %%
y_pred = classifier.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 y_pred = classifier.predict(X_test)
#       2 print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
#
# NameError: name 'X_test' is not defined

# %% [markdown]
# # Getting the accuracy scores.
#
# ## Will study in detail in class.

# %%
print (classification_report(y_test, y_pred))

print (print("Validation Accuracy: ",accuracy_score(y_test, y_pred)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 print (classification_report(y_test, y_pred))
#       3 print (print("Validation Accuracy: ",accuracy_score(y_test, y_pred)))
#
# NameError: name 'y_test' is not defined

# %% [markdown]
# # Plotting the Confusion Matrix.

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classifier.classes_)
disp.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 cm = confusion_matrix(y_test, y_pred)
#       2 disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classifier.classes_)
#       3 disp.plot()
#
# NameError: name 'y_test' is not defined

# %%
# Visualising the Training set results
from matplotlib.colors import ListedColormap
X_set, y_set = X_train, y_train
X, Y = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))

probs = classifier.predict(np.array([X.ravel(), Y.ravel()]).T).reshape(X.shape)
plt.contourf(X, Y, probs, alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X.min(), X.max())
plt.ylim(Y.min(), Y.max())

for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j, edgecolor="white")

plt.title('Logistic Regression Classifier (Training set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 3
#       1 # Visualising the Training set results
#       2 from matplotlib.colors import ListedColormap
# ----> 3 X_set, y_set = X_train, y_train
#       4 X, Y = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
#       5                      np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
#       7 probs = classifier.predict(np.array([X.ravel(), Y.ravel()]).T).reshape(X.shape)
#
# NameError: name 'y_train' is not defined

# %%
# Visualising the Test set results
X_set, y_set = X_test, y_test
X, Y = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))

probs = classifier.predict(np.array([X.ravel(), Y.ravel()]).T).reshape(X.shape)
plt.contourf(X, Y, probs, alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X.min(), X.max())
plt.ylim(Y.min(), Y.max())

for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j, edgecolor="white")

plt.title('Logistic Regression Classifier (Test set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 2
#       1 # Visualising the Test set results
# ----> 2 X_set, y_set = X_test, y_test
#       3 X, Y = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
#       4                      np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
#       6 probs = classifier.predict(np.array([X.ravel(), Y.ravel()]).T).reshape(X.shape)
#
# NameError: name 'X_test' is not defined
